# %%
from environment import NormalMoveEnv
from experiment import Experiment
from nn import BetaModel, Model, GeneralModel
from rl import Agent, Trajectory

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %% [markdown]
# # Env

# %%
exp_params = {
    'env_class': NormalMoveEnv,
    'env_params': {
        'walls': [],
        'goals': [([-10.,8.],[-8.,10.])],
        'start': ([0.,-9.9],[9.9,-7.]),
        'beta': lambda s: (s[1]>-4. and s[1]<4.)
    },
    'agents':[
        {
            'k': 5, 
            "lr": 1e-6, 
            'momentum': .9,
            'td_model_steps': 20, 
            'memory_size': 0, 
            'max_plan_size': 3,
            'model': Model
        },
        {
            "lr": 1e-6, 
            'momentum': .9,
            'td_model_steps': 20, 
            'memory_size': 0, 
            'max_plan_size': 3,
            'model': GeneralModel
        }
    ],
    'episodes_size_limit': 500,
    'runs': 100,
    'replays': 5
}

exp = Experiment(**exp_params)
exp.execute()
exp.data
# Out:
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
# c:\Users\guilherme.albarrans\OneDrive - Ame Digital\Área de Trabalho\RL\NN RL3\environment.py:29: RuntimeWarning: overflow encountered in cast
#   self.transition = transition or (lambda s,a,t,sig: (s + self.actions[a]*t + np.random.normal(0, sig, 2)).astype(np.float32))
#      run  play  model_0  model_1
# 0    0.0   0.0    236.0      NaN
# 0    0.0   1.0    104.0      NaN
# 0    0.0   2.0     51.0     80.0
# 0    0.0   3.0     56.0     76.0
# 0    0.0   4.0     97.0     52.0
# ..   ...   ...      ...      ...
# 0   99.0   0.0    230.0    225.0
# 0   99.0   1.0     94.0     50.0
# 0   99.0   2.0    108.0     42.0
# 0   99.0   3.0     93.0     32.0
# 0   99.0   4.0     35.0     42.0
#
# [500 rows x 4 columns]

# %%
exp.data.describe()
# Out:
#               run       play     model_0     model_1
# count  500.000000  500.00000  421.000000  386.000000
# mean    49.500000    2.00000  200.973872  118.751295
# std     28.894979    1.41563  176.262647   88.215676
# min      0.000000    0.00000   25.000000   27.000000
# 25%     24.750000    1.00000   57.000000   51.000000
# 50%     49.500000    2.00000  108.000000   83.500000
# 75%     74.250000    3.00000  337.000000  174.750000
# max     99.000000    4.00000  500.000000  500.000000

# %%
exp.data.loc[exp.data.play==0.0].describe()
# Out:
#               run   play     model_0     model_1
# count  100.000000  100.0   94.000000   95.000000
# mean    49.500000    0.0  369.265957  213.178947
# std     29.011492    0.0  121.730195   51.749392
# min      0.000000    0.0  162.000000  111.000000
# 25%     24.750000    0.0  249.250000  177.500000
# 50%     49.500000    0.0  347.500000  206.000000
# 75%     74.250000    0.0  500.000000  242.500000
# max     99.000000    0.0  500.000000  425.000000

# %%
exp.data.loc[exp.data.play==1.0].describe()
# Out:
#               run   play     model_0     model_1
# count  100.000000  100.0   83.000000   78.000000
# mean    49.500000    1.0  200.156627   83.038462
# std     29.011492    0.0  166.218302   54.196957
# min      0.000000    1.0   34.000000   27.000000
# 25%     24.750000    1.0   72.500000   50.000000
# 50%     49.500000    1.0  129.000000   68.500000
# 75%     74.250000    1.0  292.500000   94.000000
# max     99.000000    1.0  500.000000  291.000000

# %%
exp.data.loc[exp.data.play==2.0].describe()
# Out:
#               run   play     model_0     model_1
# count  100.000000  100.0   84.000000   76.000000
# mean    49.500000    2.0  162.357143   96.026316
# std     29.011492    0.0  171.228139   93.334091
# min      0.000000    2.0   28.000000   30.000000
# 25%     24.750000    2.0   50.750000   46.750000
# 50%     49.500000    2.0   76.000000   68.000000
# 75%     74.250000    2.0  159.000000  100.500000
# max     99.000000    2.0  500.000000  500.000000

# %%
exp.data.loc[exp.data.play==3.0].describe()
# Out:
#               run   play     model_0     model_1
# count  100.000000  100.0   81.000000   74.000000
# mean    49.500000    3.0  136.172840   84.202703
# std     29.011492    0.0  158.699149   63.575428
# min      0.000000    3.0   25.000000   31.000000
# 25%     24.750000    3.0   45.000000   46.250000
# 50%     49.500000    3.0   67.000000   70.500000
# 75%     74.250000    3.0  108.000000   91.000000
# max     99.000000    3.0  500.000000  432.000000

# %%
exp.data.loc[exp.data.play==4.0].describe()
# Out:
#               run   play     model_0     model_1
# count  100.000000  100.0   79.000000   63.000000
# mean    49.500000    4.0  109.088608   88.571429
# std     29.011492    0.0  122.060009   84.075180
# min      0.000000    4.0   27.000000   27.000000
# 25%     24.750000    4.0   43.500000   48.000000
# 50%     49.500000    4.0   73.000000   69.000000
# 75%     74.250000    4.0   96.500000   94.500000
# max     99.000000    4.0  500.000000  500.000000
